# %% [markdown]
# Before we get started, a couple of reminders to keep in mind when using iPython notebooks:
#
# - Remember that you can see from the left side of a code cell when it was last run if there is a number within the brackets.
# - When you start a new notebook session, make sure you run all of the cells up to the point where you last left off. Even if the output is still visible from when you ran the cells in your previous session, the kernel starts in a fresh state so you'll need to reload the data, etc. on a new session.
# - The previous point is useful to keep in mind if your answers do not match what is expected in the lesson's quizzes. Try reloading the data and run all of the processing steps one by one in order to make sure that you are working with the same variables and data that are at each quiz stage.
#
#
# ## Load Data from CSVs

# %% [markdown]
# https://storage.googleapis.com/supplemental_media/udacityu/5430778793/table_descriptions.txt

# %%
import unicodecsv

# %%
## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()

# %%
enrollments_filename = 'enrollments.csv'
engagement_filename = 'daily_engagement.csv'
submissions_filename = 'project_submissions.csv'

# %%
def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

# %%
#####################################
#                 1                 #
#####################################

## Read in the data from daily_engagement.csv and project_submissions.csv 
## and store the results in the below variables.
## Then look at the first row of each table.

enrollments = read_csv(enrollments_filename)
daily_engagement = read_csv(engagement_filename)
project_submissions = read_csv(submissions_filename)

# %%
enrollments
daily_engagement
project_submissions
# Out:
# [OrderedDict([('creation_date', '2015-01-14'),
#               ('completion_date', '2015-01-16'),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-10'),
#               ('completion_date', '2015-01-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-20'),
#               ('completion_date', '2015-01-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-13'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '434'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-17'),
#               ('completion_date', '2015-03-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '434'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-06'),
#               ('completion_date', '2015-04-06'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-26'),
#               ('completion_date', '2015-07-28'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-31'),
#               ('completion_date', '2015-06-02'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-29'),
#               ('completion_date', '2015-07-29'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-29'),
#               ('completion_date', '2015-07-29'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-07'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-06'),
#               ('completion_date', '2015-04-06'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-05'),
#               ('completion_date', '2015-04-05'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-13'),
#               ('completion_date', '2015-01-23'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '378'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-19'),
#               ('completion_date', '2015-04-02'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-29'),
#               ('completion_date', '2015-02-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-29'),
#               ('completion_date', '2015-02-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-08'),
#               ('completion_date', '2015-01-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-24'),
#               ('completion_date', '2015-01-07'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-11'),
#               ('completion_date', '2015-02-25'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-26'),
#               ('completion_date', '2015-03-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-06'),
#               ('completion_date', '2015-02-19'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-23'),
#               ('completion_date', '2015-07-31'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-21'),
#               ('completion_date', '2015-07-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-10'),
#               ('completion_date', '2015-07-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-18'),
#               ('completion_date', '2015-07-18'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-11'),
#               ('completion_date', '2015-06-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-10'),
#               ('completion_date', '2015-06-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-20'),
#               ('completion_date', '2015-07-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-14'),
#               ('completion_date', '2015-07-15'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-12'),
#               ('completion_date', '2015-06-12'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-31'),
#               ('completion_date', '2015-08-04'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-22'),
#               ('completion_date', '2015-06-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-11'),
#               ('completion_date', '2015-06-12'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-29'),
#               ('completion_date', '2015-06-29'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-26'),
#               ('completion_date', '2015-06-26'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-05'),
#               ('completion_date', '2015-06-09'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-31'),
#               ('completion_date', '2015-01-15'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '223'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-18'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '223'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '152'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-09'),
#               ('completion_date', '2015-03-19'),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '152'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-05'),
#               ('completion_date', '2015-03-09'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '152'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-12'),
#               ('completion_date', '2015-08-12'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-11'),
#               ('completion_date', '2015-08-12'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-06'),
#               ('completion_date', '2015-08-06'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-28'),
#               ('completion_date', '2015-07-29'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-03'),
#               ('completion_date', '2015-05-04'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-11'),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-10'),
#               ('completion_date', '2015-08-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-26'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-11'),
#               ('completion_date', '2015-03-26'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-25'),
#               ('completion_date', '2015-05-28'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-03'),
#               ('completion_date', '2015-02-17'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-26'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-24'),
#               ('completion_date', '2015-04-07'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '273'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-25'),
#               ('completion_date', '2015-08-25'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '599'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-03'),
#               ('completion_date', '2015-08-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '599'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-14'),
#               ('completion_date', '2014-12-23'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '639'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-13'),
#               ('completion_date', '2015-01-26'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '639'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-19'),
#               ('completion_date', '2015-08-19'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-12'),
#               ('completion_date', '2015-07-12'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-26'),
#               ('completion_date', '2015-07-27'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-19'),
#               ('completion_date', '2015-08-19'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '324'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-10'),
#               ('completion_date', '2015-08-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-09'),
#               ('completion_date', '2015-08-09'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-18'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-03'),
#               ('completion_date', '2015-01-07'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-09'),
#               ('completion_date', '2015-08-09'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-22'),
#               ('completion_date', '2015-03-27'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-11'),
#               ('completion_date', '2015-08-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-28'),
#               ('completion_date', '2015-07-29'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-06'),
#               ('completion_date', '2015-08-06'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-12'),
#               ('completion_date', '2015-06-12'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-12'),
#               ('completion_date', '2015-06-12'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-11'),
#               ('completion_date', '2015-06-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-16'),
#               ('completion_date', '2015-03-03'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-21'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-16'),
#               ('completion_date', '2015-02-19'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-17'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '30'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-10'),
#               ('completion_date', '2015-04-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-29'),
#               ('completion_date', '2015-06-30'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '168'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-04'),
#               ('completion_date', '2015-05-04'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-15'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-26'),
#               ('completion_date', '2015-07-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-15'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-25'),
#               ('completion_date', '2015-08-26'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-25'),
#               ('completion_date', '2015-08-25'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-11'),
#               ('completion_date', '2015-01-25'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-04'),
#               ('completion_date', '2015-05-07'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-19'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-28'),
#               ('completion_date', '2015-02-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-02'),
#               ('completion_date', '2015-08-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1206'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-24'),
#               ('completion_date', '2015-08-24'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-19'),
#               ('completion_date', '2015-07-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-20'),
#               ('completion_date', '2015-07-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-10'),
#               ('completion_date', '2015-08-10'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-16'),
#               ('completion_date', '2015-04-17'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-15'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-20'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-16'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-06'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-13'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-25'),
#               ('completion_date', '2015-04-26'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-16'),
#               ('completion_date', '2015-04-16'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-15'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-14'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-30'),
#               ('completion_date', '2015-05-01'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-15'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-13'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-12'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-23'),
#               ('completion_date', '2015-04-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-12'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-08'),
#               ('completion_date', '2015-04-08'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-12'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-05'),
#               ('completion_date', '2015-05-08'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-26'),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '156'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-09'),
#               ('completion_date', '2015-06-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-09'),
#               ('completion_date', '2015-03-18'),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '156'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-02'),
#               ('completion_date', '2015-08-03'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-08'),
#               ('completion_date', '2015-02-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-27'),
#               ('completion_date', '2015-07-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '232'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-05'),
#               ('completion_date', '2015-05-05'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-24'),
#               ('completion_date', '2015-07-24'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-23'),
#               ('completion_date', '2015-07-24'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-13'),
#               ('completion_date', '2015-06-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-01'),
#               ('completion_date', '2015-08-07'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-22'),
#               ('completion_date', '2015-07-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-14'),
#               ('completion_date', '2015-06-14'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-14'),
#               ('completion_date', '2015-06-14'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-10'),
#               ('completion_date', '2015-06-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-11'),
#               ('completion_date', '2015-08-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-02'),
#               ('completion_date', '2015-07-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-11'),
#               ('completion_date', '2015-06-11'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-13'),
#               ('completion_date', '2015-06-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-03'),
#               ('completion_date', '2015-07-03'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-28'),
#               ('completion_date', '2015-07-29'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1224'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-10'),
#               ('completion_date', '2015-07-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-30'),
#               ('completion_date', '2015-05-30'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-28'),
#               ('completion_date', '2015-05-28'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-30'),
#               ('completion_date', '2014-12-31'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-12'),
#               ('completion_date', '2015-01-01'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-05'),
#               ('completion_date', '2015-01-18'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-01'),
#               ('completion_date', '2015-07-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '189'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-28'),
#               ('completion_date', '2015-05-29'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '189'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-20'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '189'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-27'),
#               ('completion_date', '2015-08-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-06'),
#               ('completion_date', '2015-08-06'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-26'),
#               ('completion_date', '2015-07-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-23'),
#               ('completion_date', '2015-08-25'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-25'),
#               ('completion_date', '2015-06-25'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '491'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-22'),
#               ('completion_date', '2015-06-22'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-07'),
#               ('completion_date', '2015-08-07'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '491'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-24'),
#               ('completion_date', '2015-06-24'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-23'),
#               ('completion_date', '2015-06-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-02'),
#               ('completion_date', '2015-07-02'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '535'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-01'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '535'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-06'),
#               ('completion_date', '2015-06-08'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '57'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-19'),
#               ('completion_date', '2014-12-26'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '57'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-03'),
#               ('completion_date', '2015-06-05'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '57'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-10'),
#               ('completion_date', '2015-02-11'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '57'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-22'),
#               ('completion_date', '2015-07-22'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '57'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-10'),
#               ('completion_date', '2015-01-16'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '57'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-26'),
#               ('completion_date', '2015-07-26'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '57'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-22'),
#               ('completion_date', '2015-07-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '57'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-25'),
#               ('completion_date', '2015-08-25'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '61'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-23'),
#               ('completion_date', '2015-08-23'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '61'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-28'),
#               ('completion_date', '2015-06-28'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '61'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-24'),
#               ('completion_date', '2015-08-24'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '61'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-22'),
#               ('completion_date', '2015-08-22'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '61'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-07'),
#               ('completion_date', '2015-06-07'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '61'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-21'),
#               ('completion_date', '2015-07-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '375'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-20'),
#               ('completion_date', '2015-07-20'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '375'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-22'),
#               ('completion_date', '2015-05-22'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '375'),
#               ('lesson_key', '3176718735'),
# ...
#               ('completion_date', '2015-07-31'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '162'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-09'),
#               ('completion_date', '2015-06-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '162'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-23'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '181'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-10'),
#               ('completion_date', '2015-03-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '181'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-22'),
#               ('completion_date', '2015-08-23'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '525'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-05'),
#               ('completion_date', '2015-07-05'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-07'),
#               ('completion_date', '2015-04-07'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '525'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2014-12-29'),
#               ('completion_date', '2015-01-09'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '525'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-10'),
#               ('completion_date', '2015-07-16'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-20'),
#               ('completion_date', '2015-03-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-26'),
#               ('completion_date', '2015-02-07'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '525'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-01'),
#               ('completion_date', '2015-04-05'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-16'),
#               ('completion_date', '2015-07-18'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-18'),
#               ('completion_date', '2015-07-18'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-20'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-05'),
#               ('completion_date', '2015-03-17'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-08'),
#               ('completion_date', '2015-08-08'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-01'),
#               ('completion_date', '2015-08-07'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-14'),
#               ('completion_date', '2015-07-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-07'),
#               ('completion_date', '2015-07-10'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-15'),
#               ('completion_date', '2015-07-16'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-29'),
#               ('completion_date', '2015-05-30'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-21'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-20'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-18'),
#               ('completion_date', '2015-07-19'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-30'),
#               ('completion_date', '2015-06-04'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-19'),
#               ('completion_date', '2015-05-21'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-22'),
#               ('completion_date', '2015-08-24'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-13'),
#               ('completion_date', '2015-07-20'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-28'),
#               ('completion_date', '2015-04-29'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-01'),
#               ('completion_date', '2015-02-16'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-28'),
#               ('completion_date', '2015-06-28'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-27'),
#               ('completion_date', '2015-06-27'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-14'),
#               ('completion_date', '2015-04-17'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-12'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-24'),
#               ('completion_date', '2015-08-24'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-19'),
#               ('completion_date', '2015-04-20'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-28'),
#               ('completion_date', '2015-03-15'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-13'),
#               ('completion_date', '2015-07-13'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-17'),
#               ('completion_date', '2015-01-31'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-16'),
#               ('completion_date', '2015-04-16'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-07'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '634'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-02-01'),
#               ('completion_date', '2015-02-16'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-04-15'),
#               ('completion_date', '2015-04-15'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-29'),
#               ('completion_date', '2015-04-13'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-29'),
#               ('completion_date', '2015-03-31'),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-29'),
#               ('completion_date', '2015-04-07'),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '634'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-27'),
#               ('completion_date', '2015-07-28'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-21'),
#               ('completion_date', '2015-07-21'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-05'),
#               ('completion_date', '2015-08-05'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-05'),
#               ('completion_date', '2015-08-05'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-07-17'),
#               ('completion_date', '2015-07-18'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-26'),
#               ('completion_date', '2015-05-26'),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-08-18'),
#               ('completion_date', '2015-08-19'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-06-16'),
#               ('completion_date', '2015-06-16'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-05-26'),
#               ('completion_date', '2015-06-03'),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-03-09'),
#               ('completion_date', '2015-03-26'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '369'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', '2015-01-12'),
#               ('completion_date', '2015-01-23'),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '369'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  ...]

# %% [markdown]
# ## Fixing Data Types

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# OrderedDict([('account_key', '448'),
#              ('status', 'canceled'),
#              ('join_date', datetime.datetime(2014, 11, 10, 0, 0)),
#              ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('days_to_cancel', 65),
#              ('is_udacity', True),
#              ('is_canceled', True)])

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[0]
# Out:
# OrderedDict([('acct', '0'),
#              ('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#              ('num_courses_visited', 1),
#              ('total_minutes_visited', 11.6793745),
#              ('lessons_completed', 0),
#              ('projects_completed', 0)])

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[0]
# Out:
# OrderedDict([('creation_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('completion_date', datetime.datetime(2015, 1, 16, 0, 0)),
#              ('assigned_rating', 'UNGRADED'),
#              ('account_key', '256'),
#              ('lesson_key', '3176718735'),
#              ('processing_state', 'EVALUATED')])

# %% [markdown]
# Note when running the above cells that we are actively changing the contents of our data variables. If you try to run these cells multiple times in the same session, an error will occur.
#
# ## Investigating the Data

# %%
#####################################
#                 2                 #
#####################################

## Find the total number of rows and the number of unique students (account keys)
## in each table.

# %%
for engagement_record in daily_engagement:
    engagement_record['account_key'] = engagement_record['acct']
    del[engagement_record['acct']]

# %%
def get_unique_students(data):
    unique_students = set()
    for data_point in data:
        unique_students.add(data_point['account_key'])
    return unique_students

# %%
unique_enrollment_students = get_unique_students(enrollments)
len(unique_enrollment_students)
# Out:
# 1302

# %%
len(daily_engagement)
# Out:
# 136240

# %%
unique_engagement_students = get_unique_students(daily_engagement)
len(unique_engagement_students)
# Out:
# 1237

# %%
len(project_submissions)
# Out:
# 3642

# %%
unique_project_submitters = get_unique_students(project_submissions)
len(unique_project_submitters)
# Out:
# 743

# %%
for engagement_record in daily_engagement:
    engagement_record['account_key'] = engagement_record['acct']
    del[engagement_record['acct']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b05236702cf3> in <module>()
#       1 for engagement_record in daily_engagement:
# ----> 2     engagement_record['account_key'] = engagement_record['acct']
#       3     del[engagement_record['acct']]
#
# KeyError: 'acct'

# %%
# Out:
# '0'

# %% [markdown]
# ## Problems in the Data

# %%
#####################################
#                 3                 #
#####################################

## Rename the "acct" column in the daily_engagement table to "account_key".
daily_engagement[0]['account_key']
# Out:
# '0'

# %%
# Out:
# OrderedDict([('account_key', '1304'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 59), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '1304'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '1101'), ('status', 'current'), ('join_date', datetime.datetime(2015, 2, 25, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', True), ('is_canceled', False)])
# 3

# %% [markdown]
# ## Missing Engagement Records

# %%
# Out:
# 1302
# 1237
# 743

# %%
# Out:
# OrderedDict([('account_key', '1219'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 12, 0, 0)), ('days_to_cancel', 0), ('is_udacity', False), ('is_canceled', True)])

# %%
#####################################
#                 4                 #
#####################################

## Find any one student enrollments where the student is missing from the daily engagement table.
## Output that enrollment.

for enrollment in enrollments:
    student = enrollment['account_key']
    if student not in unique_engagement_students:
        print(enrollment)
        break
# Out:
# OrderedDict([('account_key', '1219'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 12, 0, 0)), ('days_to_cancel', 0), ('is_udacity', False), ('is_canceled', True)])

# %% [markdown]
# ## Checking for More Problem Records

# %%
#####################################
#                 5                 #
#####################################

## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.

num_problem_students = 0
for enrollment in enrollments:
    student = enrollment['account_key']
    if (student not in unique_engagement_students and enrollment['join_date'] != enrollment['cancel_date']):
        print(enrollment)
        num_problem_students += 1
num_problem_students
# Out:
# OrderedDict([('account_key', '1304'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 59), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '1304'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '1101'), ('status', 'current'), ('join_date', datetime.datetime(2015, 2, 25, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', True), ('is_canceled', False)])
# 3

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print(len(non_udacity_enrollments))
print(len(non_udacity_engagement))
print(len(non_udacity_submissions))
# Out:
# 1622
# 135656
# 3634

# %% [markdown]
# ## Refining the Question

# %%
# Out:
# 995

# %%
#####################################
#                 6                 #
#####################################

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.

paid_students = {}
for enrollment in non_udacity_enrollments:
    if (not enrollment['is_canceled'] or enrollment['days_to_cancel']>7):
        account_key = enrollment['account_key']
        enrollment_date = enrollment['join_date']
        if (account_key not in paid_students or enrollment_date > paid_students[account_key]):
            paid_students[account_key] = enrollment_date
len(paid_students)
# Out:
# 995

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7 and time_delta.days >= 0

# %%
def remove_free_trial_cancels(data):
    new_data = []
    for data_point in data:
        if data_point['account_key'] in paid_students:
            new_data.append(data_point)
    return new_data

# %%
paid_enrollments = remove_free_trial_cancels(non_udacity_enrollments)
paid_engagement = remove_free_trial_cancels(non_udacity_engagement)
paid_submissions = remove_free_trial_cancels(non_udacity_submissions)

print(len(paid_enrollments))
print(len(paid_engagement))
print(len(paid_submissions))
# Out:
# 1293
# 134549
# 3618

# %%
# Número de visitas na primeira semana
for engagement_record in paid_engagement:
    if engagement_record['num_courses_visited'] > 0:
        engagement_record['has_visited'] = 1
    else:
        engagement_record['has_visited'] = 0

# %%
#####################################
#                 7                 #
#####################################

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week = []

for engagement_record in paid_engagement:
    account_key = engagement_record['account_key']
    join_date = paid_students[account_key]
    engagement_record_date = engagement_record['utc_date']
    if within_one_week(join_date, engagement_record_date):
        paid_engagement_in_first_week.append(engagement_record)
len(paid_engagement_in_first_week)
# Out:
# 6919

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of engagement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
def group_data(data, key_name):
    group_data = defaultdict(list)
    for data_point in data:
        key = data_point[key_name]
        group_data[key].append(data_point)
    return group_data
        

engagement_by_account = group_data(paid_engagement_in_first_week, 'account_key')

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
def sum_grouped_items(grouped_data, field_name):
    summed_data = {}
    
    for key, data_points in grouped_data.items():
        total = 0
        for data_point in data_points:
            total += data_point[field_name]
        summed_data[key] = total
    return summed_data

total_minutes_by_accounts = sum_grouped_items(engagement_by_account, 'total_minutes_visited')

# %%
import numpy as np

# Summarize the data about minutes spent in the classroom
def describe_data(data):
    total_minute_statistics = []
    for total_minute in data.values():
        total_minute_statistics.append(total_minute)
        
    print('Mean:', np.mean(total_minute_statistics))
    print('Standard deviation:', np.std(total_minute_statistics))
    print('Minimum:', np.min(total_minute_statistics))
    print('Maximum:', np.max(total_minute_statistics))

# %%
total_minutes = describe_data(total_minutes_by_accounts)
# Out:
# Mean: 306.70832675342825
# Standard deviation: 412.99693340852957
# Minimum: 0.0
# Maximum: 3564.7332644989997

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
# max(total_minutes_by_account.items(), key=lambda pair: pair[1])

# %%
#####################################
#                 8                 #
#####################################

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.

student_with_max_minutes = None
max_minutes = 0

for student, total_minutes in total_minutes_by_account.items():
    if total_minutes > max_minutes:
        max_minutes = total_minutes
        student_with_max_minutes = student
max_minutes
# Out:
# 3564.7332644989997

# %%
for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] == student_with_max_minutes:
        print(engagement_record)
# Out:
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 9, 0, 0)), ('num_courses_visited', 4), ('total_minutes_visited', 850.519339666), ('lessons_completed', 4), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 10, 0, 0)), ('num_courses_visited', 6), ('total_minutes_visited', 872.633923334), ('lessons_completed', 6), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 11, 0, 0)), ('num_courses_visited', 2), ('total_minutes_visited', 777.018903666), ('lessons_completed', 6), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 12, 0, 0)), ('num_courses_visited', 1), ('total_minutes_visited', 294.568774), ('lessons_completed', 2), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 13, 0, 0)), ('num_courses_visited', 3), ('total_minutes_visited', 471.2139785), ('lessons_completed', 1), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 14, 0, 0)), ('num_courses_visited', 2), ('total_minutes_visited', 298.778345333), ('lessons_completed', 1), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 1)])
# OrderedDict([('utc_date', datetime.datetime(2015, 7, 15, 0, 0)), ('num_courses_visited', 0), ('total_minutes_visited', 0.0), ('lessons_completed', 0), ('projects_completed', 0), ('account_key', '163'), ('has_visited', 0)])

# %% [markdown]
# ## Lessons Completed in First Week

# %%
#####################################
#                 9                 #
#####################################

## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.

lessons_completed_by_account = sum_grouped_items(engagement_by_account, 'lessons_completed')
describe_data(lessons_completed_by_account)
# Out:
# Mean: 1.636180904522613
# Standard deviation: 3.002561299829423
# Minimum: 0
# Maximum: 36

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #
######################################

## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.

days_visited_by_account = sum_grouped_items(engagement_by_account, 'has_visited')
describe_data(days_visited_by_account)
# Out:
# Mean: 2.8673366834170855
# Standard deviation: 2.2551980029196814
# Minimum: 0
# Maximum: 7

# %% [markdown]
# ## Splitting out Passing Students

# %%
######################################
#                 11                 #
######################################

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

passing_engagement =
non_passing_engagement =

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
######################################

## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
######################################

## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
######################################

## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
